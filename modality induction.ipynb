# %%
! pip install -q keras

# %%
import numpy as np
import math
import random
import pandas as pd
import os
import matplotlib.pyplot as plt
import cv2
import glob
from tqdm import tqdm
import pickle
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt
from scipy.spatial.distance import cdist

from keras.optimizers import *
from keras.models import Model
from keras.layers import *
from keras import layers
from tensorflow.keras.callbacks import *
from keras import backend as K
import keras
import tensorflow as tf

import google.colab.files

# %% [markdown]
# 1. Define configurations

# %%
random.seed(1234)

class Config():
    def __init__(self):
        self.frame_l = 32 # the length of frames
        self.joint_n = 12 # the number of joints
        self.joint_n = 22 # the number of joints
        self.joint_d = 3 # the dimension of joints
        self.clc_coarse = 14 # the number of coarse class
        self.clc_fine = 28 # the number of fine-grained class
        self.feat_d = 231
        self.filters = 64
C = Config()

# %% [markdown]
# 2. Define data processing functions

# %%
# Temple resizing function
import numpy as np
import os
import pandas as pd
import random
import scipy.ndimage.interpolation as inter
from scipy.signal import medfilt

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

###################################################################################


#Rescale to be 64 frames
def zoom(p,target_l=64,joints_num=25,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim])
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
    return p_new

def sampling_frame(p,C):
    full_l = p.shape[0] # full length
    if random.uniform(0,1)<0.5: # aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        s = random.randint(0, full_l-int(valid_l))
        e = s+valid_l # sample end point
        p = p[int(s):int(e),:,:]
    else: # without aligment sampling
        valid_l = np.round(np.random.uniform(0.9,1)*full_l)
        index = np.sort(np.random.choice(range(0,full_l),int(valid_l),replace=False))
        p = p[index,:,:]
    p = zoom(p,C.frame_l,C.joint_n,C.joint_d)
    return p

from scipy.spatial.distance import cdist
def get_CG(p,C):
    M = []
    iu = np.triu_indices(C.joint_n,1,C.joint_n)
    for f in range(C.frame_l):
        #distance max
        d_m = cdist(p[f],np.concatenate([p[f],np.zeros([1,C.joint_d])]),'euclidean')
        d_m = d_m[iu]
        M.append(d_m)
    M = np.stack(M)
    return M

def normlize_range(p):
    # normolize to start point, use the center for hand case
    p[:,:,0] = p[:,:,0]-np.mean(p[:,:,0])
    p[:,:,1] = p[:,:,1]-np.mean(p[:,:,1])
    p[:,:,2] = p[:,:,2]-np.mean(p[:,:,2])
    return p

def cm_analysis(y_true, y_pred, filename, labels, ymap=None, figsize=(8,8)):
    """
    Generate matrix plot of confusion matrix with pretty annotations.
    The plot image is saved to disk.
    args:
      y_true:    true label of the data, with shape (nsamples,)
      y_pred:    prediction of the data, with shape (nsamples,)
      filename:  filename of figure file to save
      labels:    string array, name the order of class labels in the confusion matrix.
                 use `clf.classes_` if using scikit-learn models.
                 with shape (nclass,).
      ymap:      dict: any -> string, length == nclass.
                 if not None, map the labels & ys to more understandable strings.
                 Caution: original y_true, y_pred and labels must align.
      figsize:   the size of the figure plotted.
    """
    if ymap is not None:
        y_pred = [ymap[yi] for yi in y_pred]
        y_true = [ymap[yi] for yi in y_true]
        labels = [ymap[yi] for yi in labels]
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                #annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                annot[i, j] = '%.1f' % (p)
            elif c == 0:
                annot[i, j] = ''
            else:
                #annot[i, j] = '%.1f%%\n%d' % (p, c)
                annot[i, j] = '%.1f' % (p)
    cm = pd.DataFrame(cm, index=labels, columns=labels)
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    sns.heatmap(cm, annot=annot, fmt='', ax=ax, cbar=False, cmap="YlGnBu")
    plt.savefig(filename)

# %% [markdown]
# 3. Define network

# %%
def poses_diff(x):
    H, W = x.get_shape()[1],x.get_shape()[2]
    x = tf.subtract(x[:,1:,...],x[:,:-1,...])
    x = tf.image.resize(x,size=[H,W])
    return x

def pose_motion(P,frame_l):
    P_diff_slow = Lambda(lambda x: poses_diff(x))(P)
    P_diff_slow = Reshape((frame_l,-1))(P_diff_slow)
    P_fast = Lambda(lambda x: x[:,::2,...])(P)
    P_diff_fast = Lambda(lambda x: poses_diff(x))(P_fast)
    P_diff_fast = Reshape((int(frame_l/2),-1))(P_diff_fast)

    print(P_diff_slow.shape, P_diff_fast.shape)
    return P_diff_slow, P_diff_fast

def c1D(x,filters,kernel):
    x = Conv1D(filters, kernel_size=kernel,padding='same',use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def block(x,filters):
    x = c1D(x,filters,3)
    x = c1D(x,filters,3)
    return x

def d1D(x,filters):
    x = Dense(filters,use_bias=False)(x)
    x = BatchNormalization()(x)
    x = LeakyReLU(alpha=0.2)(x)
    return x

def build_FM(frame_l=32,joint_n=22,joint_d=2,feat_d=231,filters=16):
    M = Input(shape=(frame_l,feat_d))
    P = Input(shape=(frame_l,joint_n,joint_d))
    D = Input(name='D', shape=(frame_l,21))
    A = Input(name='A', shape=(frame_l,21))

    diff_slow, diff_fast = pose_motion(P, frame_l)

    # diff_slow, _ = angle_distance(P, stride=1)
    # diff_fast, _ = angle_distance(P, stride=2)
    # print(diff_slow)

    x = c1D(M,filters*2,1)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,3)
    x = SpatialDropout1D(0.1)(x)
    x = c1D(x,filters,1)
    x = MaxPooling1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x_d_slow = c1D(diff_slow,filters*2,1)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,3)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)
    x_d_slow = c1D(x_d_slow,filters,1)
    x_d_slow = MaxPool1D(2)(x_d_slow)
    x_d_slow = SpatialDropout1D(0.1)(x_d_slow)

    x_d_fast = c1D(diff_fast,filters*2,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,3)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)
    x_d_fast = c1D(x_d_fast,filters,1)
    x_d_fast = SpatialDropout1D(0.1)(x_d_fast)

    d = c1D(D,filters*2,1)
    d = SpatialDropout1D(0.1)(d)
    d = c1D(d,filters,3)
    d = SpatialDropout1D(0.1)(d)
    d = c1D(d,filters,1)
    d = MaxPooling1D(2)(d)
    d = SpatialDropout1D(0.1)(d)

    a = c1D(A,filters*2,1)
    a = SpatialDropout1D(0.1)(a)
    a = c1D(a,filters,3)
    a = SpatialDropout1D(0.1)(a)
    a = c1D(a,filters,1)
    a = MaxPooling1D(2)(a)
    a = SpatialDropout1D(0.1)(a)

    x = concatenate([x,x_d_slow,x_d_fast,d,a])
    x = block(x,filters*2)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*4)
    x = MaxPool1D(2)(x)
    x = SpatialDropout1D(0.1)(x)

    x = block(x,filters*8)
    x = SpatialDropout1D(0.1)(x)

    return Model(inputs=[M,P,D,A],outputs=x)


def build_DD_Net(frame_l=32,joint_n=22,joint_d=3,feat_d=231,clc_num=14,filters=16):
    M = Input(name='M', shape=(frame_l,feat_d))
    P = Input(name='P', shape=(frame_l,joint_n,joint_d))
    D = Input(name='D', shape=(frame_l,21))
    A = Input(name='A', shape=(frame_l,21))

    FM = build_FM(frame_l,joint_n,joint_d,feat_d,filters)

    x = FM([M,P,D,A])

    x = GlobalMaxPool1D()(x)

    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = d1D(x,128)
    x = Dropout(0.5)(x)
    x = Dense(clc_num, activation='softmax')(x)

    ######################Self-supervised part
    model = Model(inputs=[M,P,D,A],outputs=x)
    return model

# %%
DD_Net = build_DD_Net(C.frame_l,C.joint_n,C.joint_d,C.feat_d,C.clc_coarse,C.filters)
DD_Net.summary()
# Out:
# (None, 32, 66) (None, 16, 66)
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  M (InputLayer)              [(None, 32, 231)]            0         []
#
#  P (InputLayer)              [(None, 32, 22, 3)]          0         []
#
#  D (InputLayer)              [(None, 32, 21)]             0         []
#
#  A (InputLayer)              [(None, 32, 21)]             0         []
#
#  model_6 (Functional)        (None, 4, 512)               1854080   ['M[0][0]',
#                                                                      'P[0][0]',
#                                                                      'D[0][0]',
#                                                                      'A[0][0]']
#
#  global_max_pooling1d_3 (Gl  (None, 512)                  0         ['model_6[0][0]']
#  obalMaxPooling1D)
#
#  dense_9 (Dense)             (None, 128)                  65536     ['global_max_pooling1d_3[0][0]
#                                                                     ']
#
#  batch_normalization_90 (Ba  (None, 128)                  512       ['dense_9[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_90 (LeakyReLU)  (None, 128)                  0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  dropout_6 (Dropout)         (None, 128)                  0         ['leaky_re_lu_90[0][0]']
#
#  dense_10 (Dense)            (None, 128)                  16384     ['dropout_6[0][0]']
#
#  batch_normalization_91 (Ba  (None, 128)                  512       ['dense_10[0][0]']
#  tchNormalization)
#
#  leaky_re_lu_91 (LeakyReLU)  (None, 128)                  0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  dropout_7 (Dropout)         (None, 128)                  0         ['leaky_re_lu_91[0][0]']
#
#  dense_11 (Dense)            (None, 14)                   1806      ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 1938830 (7.40 MB)
# Trainable params: 1932174 (7.37 MB)
# Non-trainable params: 6656 (26.00 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# 4. Load dataset (download GT_train_1.pkl and  GT_test_1.pkl from github )

# %%
# !wget https://github.com/fandulu/DD-Net/archive/master.zip
# !unzip master.zip
# !rm master.zip
# Out:
# --2024-05-07 16:34:19--  https://github.com/fandulu/DD-Net/archive/master.zip
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master [following]
# --2024-05-07 16:34:19--  https://codeload.github.com/fandulu/DD-Net/zip/refs/heads/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.116.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.116.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [           <=>      ]  79.09M  13.5MB/s    in 5.9s
#
# 2024-05-07 16:34:25 (13.5 MB/s) - ‘master.zip’ saved [82934337]
#
# Archive:  master.zip
# f26a9994b0bafc41096fa269eab89c2757d71499
#    creating: DD-Net-master/
#   inflating: DD-Net-master/.gitignore
#    creating: DD-Net-master/JHMDB/
#   inflating: DD-Net-master/JHMDB/README.md
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_heavy.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_lite.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_1D_middle.ipynb
#   inflating: DD-Net-master/JHMDB/jhmdb_data_preprocessing.ipynb
#   inflating: DD-Net-master/JHMDB/utils.py
#    creating: DD-Net-master/JHMDB/weights/
#  extracting: DD-Net-master/JHMDB/weights/__init__.py
#   inflating: DD-Net-master/LICENSE
#   inflating: DD-Net-master/README.md
#    creating: DD-Net-master/SHREC/
#   inflating: DD-Net-master/SHREC/README.md
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_coarse_1D_lite.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_data_preprocessing.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_heavy.ipynb
#   inflating: DD-Net-master/SHREC/SHREC_fine_1D_lite.ipynb
#    creating: DD-Net-master/SHREC/images/
#   inflating: DD-Net-master/SHREC/images/SHREC_14.png
#   inflating: DD-Net-master/SHREC/images/SHREC_28.png
#   inflating: DD-Net-master/SHREC/utils.py
#    creating: DD-Net-master/SHREC/weights/
#  extracting: DD-Net-master/SHREC/weights/.gitkeep
#  extracting: DD-Net-master/SHREC/weights/__init__.py
#    creating: DD-Net-master/data/
#    creating: DD-Net-master/data/JHMDB/
#   inflating: DD-Net-master/data/JHMDB/GT_test_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_test_3.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_1.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_2.pkl
#   inflating: DD-Net-master/data/JHMDB/GT_train_3.pkl
#   inflating: DD-Net-master/data/JHMDB/joint_positions.zip
#   inflating: DD-Net-master/data/JHMDB/splits.zip
#    creating: DD-Net-master/data/SHREC/
#  extracting: DD-Net-master/data/SHREC/__init__.py
#   inflating: DD-Net-master/data/SHREC/test.pickle
#   inflating: DD-Net-master/data/SHREC/test.pkl
#   inflating: DD-Net-master/data/SHREC/train.pickle
#   inflating: DD-Net-master/data/SHREC/train.pkl
#    creating: DD-Net-master/mics/
#  extracting: DD-Net-master/mics/__init__.py
#   inflating: DD-Net-master/mics/demo.png
#   inflating: DD-Net-master/mics/look.gif
#   inflating: DD-Net-master/mics/paper.png

# %% [markdown]
# 5. Running codes

# %%
import numpy as np

def angle_between_vectors(v1, v2):
    dot_product = np.dot(v1, v2)
    norm_v1 = np.linalg.norm(v1)
    norm_v2 = np.linalg.norm(v2)
    # Ensure input to arccos is within valid range
    dot_product /= (norm_v1 * norm_v2)
    dot_product = np.clip(dot_product, -1, 1)
    return np.arccos(dot_product)

# Sample data for 'a' representing hand points across time
# a = np.random.rand(32, 22, 3)  # Assuming 5 time steps, 22 hand points, and 3 dimensions (x, y, z)

bones = np.array([
    [0, 1], [0, 2], [2, 3], [3, 4], [4, 5], [1, 6], [6, 7], [7, 8], [8, 9],
    [1, 10], [10, 11], [11, 12], [12, 13], [1, 14], [14, 15], [15, 16], [16, 17],
    [1, 18], [18, 19], [19, 20], [20, 21]
])

def angle_distance(a, stride=1):
    # Initialize arrays to store angle differences and distance differences
    num_frames = len(a)
    num_bones = len(bones)
    num_steps = (num_frames - 1) // stride

    angle_differences = np.zeros((num_steps, num_bones))
    distance_differences = np.zeros((num_steps, num_bones))

    # Iterate through each time step in 'a' with the specified stride
    for i in range(stride, num_frames, stride):
        # Iterate through each bone in 'bones'
        for j, bone in enumerate(bones):
            # Extract the indices of the points connected by the bone
            point1_index, point2_index = bone

            # Get the coordinates of the points from the current and previous time steps
            point1_coords_current = a[i][point1_index]
            point2_coords_current = a[i][point2_index]
            point1_coords_prev = a[i-stride][point1_index]
            point2_coords_prev = a[i-stride][point2_index]

            # Calculate the vectors representing the bones at the current and previous time steps
            bone_vector_current = point2_coords_current - point1_coords_current
            bone_vector_prev = point2_coords_prev - point1_coords_prev

            # Calculate the angle between the bone vectors
            angle = angle_between_vectors(bone_vector_current, bone_vector_prev)
            angle_differences[i // stride - 1, j] = angle

            # Calculate the distance between the bone endpoints at the current and previous time steps
            distance = np.linalg.norm(point2_coords_current - point1_coords_current) - np.linalg.norm(point2_coords_prev - point1_coords_prev)
            distance_differences[i // stride - 1, j] = distance

    return angle_differences, distance_differences

# # Print the angle and distance differences


# angle_differences, distance_differences = angle_distance(X_1, stride=2)
# print("Angle differences shape:", angle_differences.shape)
# print("Distance differences shape:", distance_differences.shape)

# %%
Train = pickle.load(open("/content/DD-Net-master/data/SHREC/train.pkl", "rb"))
Test = pickle.load(open("/content/DD-Net-master/data/SHREC/test.pkl", "rb"))

X_0 = []
X_1 = []
D = []
A = []
Y = []

for i in tqdm(range(len(Train['pose']))):
    p1 = np.copy(Train['pose'][i]).reshape([-1,22,3])
    p2 = np.copy(Train['pose'][i]).reshape([-1,22,3])

    p1 = zoom(p1,target_l=32,joints_num=C.joint_n,joints_dim=C.joint_d)
    p1 = normlize_range(p1)

    p2 = zoom(p2,target_l=33,joints_num=C.joint_n,joints_dim=C.joint_d)
    p2 = normlize_range(p2)

    label = np.zeros(C.clc_coarse)
    label[Train['coarse_label'][i]-1] = 1

    M = get_CG(p1,C)
    angle_differences, distance_differences = angle_distance(p2, stride=1)

    D.append(distance_differences)
    A.append(angle_differences)

    X_0.append(M)
    X_1.append(p1)
    Y.append(label)

X_0 = np.stack(X_0)
X_1 = np.stack(X_1)
Y = np.stack(Y)
D = np.stack(D)
A = np.stack(A)
# Out:
#   0%|          | 0/1960 [00:00<?, ?it/s]<ipython-input-4-0acc17230e16>:23: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 1960/1960 [01:25<00:00, 23.02it/s]

# %%
D.shape
# Out:
# (1960, 32, 21)

# %%
for i in Train.keys():
  print(i)
# Out:
# pose
# coarse_label
# fine_label

# %%
pose = Train['pose']
coarse_label = Train['coarse_label']
fine_label = Train['fine_label']
a = pose[0].reshape([-1,22,3])

def zoom(p,target_l=33,joints_num=22,joints_dim=3):
    l = p.shape[0]
    p_new = np.empty([target_l,joints_num,joints_dim])
    for m in range(joints_num):
        for n in range(joints_dim):
            p[:,m,n] = medfilt(p[:,m,n],3)
            p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
    return p_new

a = zoom(a)
a = normlize_range(a)
M = get_CG(a,C)
print(a.shape)
# a = a.reshape(32, 22, 3)
# Out:
# (33, 22, 3)
# <ipython-input-12-4661a574547a>:12: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]

# %%
X_test_0 = []
X_test_1 = []
Y_test = []
D_test = []
A_test = []

for i in tqdm(range(len(Test['pose']))):
    p1 = np.copy(Test['pose'][i]).reshape([-1,22,3])
    p2 = np.copy(Test['pose'][i]).reshape([-1,22,3])

    p1 = zoom(p1,target_l=32,joints_num=C.joint_n,joints_dim=C.joint_d)
    p1 = normlize_range(p1)

    p2 = zoom(p2,target_l=33,joints_num=C.joint_n,joints_dim=C.joint_d)
    p2 = normlize_range(p2)

    label = np.zeros(C.clc_coarse)
    label[Test['coarse_label'][i]-1] = 1

    M = get_CG(p1,C)
    angle_differences, distance_differences = angle_distance(p2, stride=1)

    D_test.append(distance_differences)
    A_test.append(angle_differences)
    X_test_0.append(M)
    X_test_1.append(p1)
    Y_test.append(label)

X_test_0 = np.stack(X_test_0)
X_test_1 = np.stack(X_test_1)
Y_test = np.stack(Y_test)
D_test = np.stack(D_test)
A_test = np.stack(A_test)
# Out:
#   0%|          | 0/840 [00:00<?, ?it/s]<ipython-input-12-4661a574547a>:12: DeprecationWarning: Please use `zoom` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   p_new[:,m,n] = inter.zoom(p[:,m,n],target_l/l)[:target_l]
# 100%|██████████| 840/840 [00:48<00:00, 17.27it/s]

# %%
# it may takes several times to reach the reported performance
lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1,D,A],Y,
            batch_size=len(Y),
            epochs=400,
            verbose=True,
            shuffle=True,
            callbacks=[lrScheduler],
            validation_data=[(X_test_0,X_test_1,D_test,A_test),Y_test]
            )

lr = 1e-4
DD_Net.compile(loss="categorical_crossentropy",optimizer=keras.optimizers.Adam(lr),metrics=['accuracy'])
lrScheduler = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, cooldown=5, min_lr=5e-6)
history = DD_Net.fit([X_0,X_1,D,A],Y,
            batch_size=len(Y),
            epochs=500,
            verbose=True,
            shuffle=True,
            callbacks=[lrScheduler],
            validation_data=[(X_test_0,X_test_1,D_test,A_test),Y_test]
            )
# Out:
# Epoch 1/400
# 1/1 [==============================] - 46s 46s/step - loss: 3.5180 - accuracy: 0.0633 - val_loss: 2.6391 - val_accuracy: 0.0845 - lr: 1.0000e-04
# Epoch 2/400
# 1/1 [==============================] - 0s 291ms/step - loss: 3.3456 - accuracy: 0.0801 - val_loss: 2.6385 - val_accuracy: 0.0690 - lr: 1.0000e-04
# Epoch 3/400
# 1/1 [==============================] - 0s 271ms/step - loss: 3.2926 - accuracy: 0.0898 - val_loss: 2.6382 - val_accuracy: 0.0690 - lr: 1.0000e-04
# Epoch 4/400
# 1/1 [==============================] - 0s 254ms/step - loss: 3.2243 - accuracy: 0.1015 - val_loss: 2.6383 - val_accuracy: 0.0690 - lr: 1.0000e-04
# Epoch 5/400
# 1/1 [==============================] - 0s 274ms/step - loss: 3.1875 - accuracy: 0.1051 - val_loss: 2.6386 - val_accuracy: 0.0690 - lr: 1.0000e-04
# Epoch 6/400
# 1/1 [==============================] - 0s 276ms/step - loss: 3.1024 - accuracy: 0.1199 - val_loss: 2.6390 - val_accuracy: 0.0964 - lr: 1.0000e-04
# Epoch 7/400
# 1/1 [==============================] - 0s 254ms/step - loss: 3.0316 - accuracy: 0.1301 - val_loss: 2.6395 - val_accuracy: 0.0690 - lr: 1.0000e-04
# Epoch 8/400
# 1/1 [==============================] - 0s 251ms/step - loss: 3.0007 - accuracy: 0.1301 - val_loss: 2.6400 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 9/400
# 1/1 [==============================] - 0s 270ms/step - loss: 2.9716 - accuracy: 0.1388 - val_loss: 2.6408 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 10/400
# 1/1 [==============================] - 0s 270ms/step - loss: 2.9812 - accuracy: 0.1388 - val_loss: 2.6416 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 11/400
# 1/1 [==============================] - 0s 266ms/step - loss: 2.8801 - accuracy: 0.1418 - val_loss: 2.6426 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 12/400
# 1/1 [==============================] - 0s 287ms/step - loss: 2.8300 - accuracy: 0.1541 - val_loss: 2.6438 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 13/400
# 1/1 [==============================] - 0s 285ms/step - loss: 2.8295 - accuracy: 0.1571 - val_loss: 2.6450 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 14/400
# 1/1 [==============================] - 0s 287ms/step - loss: 2.8480 - accuracy: 0.1449 - val_loss: 2.6464 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 15/400
# 1/1 [==============================] - 0s 295ms/step - loss: 2.7544 - accuracy: 0.1561 - val_loss: 2.6479 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 16/400
# 1/1 [==============================] - 0s 269ms/step - loss: 2.7816 - accuracy: 0.1719 - val_loss: 2.6495 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 17/400
# 1/1 [==============================] - 0s 255ms/step - loss: 2.6782 - accuracy: 0.1898 - val_loss: 2.6512 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 18/400
# 1/1 [==============================] - 0s 281ms/step - loss: 2.7349 - accuracy: 0.1821 - val_loss: 2.6529 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 19/400
# 1/1 [==============================] - 0s 287ms/step - loss: 2.6689 - accuracy: 0.1883 - val_loss: 2.6548 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 20/400
# 1/1 [==============================] - 0s 259ms/step - loss: 2.6178 - accuracy: 0.2097 - val_loss: 2.6568 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 21/400
# 1/1 [==============================] - 0s 264ms/step - loss: 2.6170 - accuracy: 0.2051 - val_loss: 2.6588 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 22/400
# 1/1 [==============================] - 0s 253ms/step - loss: 2.5694 - accuracy: 0.2077 - val_loss: 2.6610 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 23/400
# 1/1 [==============================] - 0s 247ms/step - loss: 2.5224 - accuracy: 0.2184 - val_loss: 2.6633 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 24/400
# 1/1 [==============================] - 0s 269ms/step - loss: 2.4781 - accuracy: 0.2311 - val_loss: 2.6657 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 25/400
# 1/1 [==============================] - 0s 306ms/step - loss: 2.4684 - accuracy: 0.2240 - val_loss: 2.6681 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 26/400
# 1/1 [==============================] - 0s 237ms/step - loss: 2.4689 - accuracy: 0.2245 - val_loss: 2.6706 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 27/400
# 1/1 [==============================] - 0s 288ms/step - loss: 2.3803 - accuracy: 0.2546 - val_loss: 2.6732 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 28/400
# 1/1 [==============================] - 0s 274ms/step - loss: 2.3899 - accuracy: 0.2556 - val_loss: 2.6758 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 29/400
# 1/1 [==============================] - 0s 310ms/step - loss: 2.3958 - accuracy: 0.2485 - val_loss: 2.6785 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 30/400
# 1/1 [==============================] - 0s 341ms/step - loss: 2.3769 - accuracy: 0.2597 - val_loss: 2.6812 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 31/400
# 1/1 [==============================] - 0s 325ms/step - loss: 2.3072 - accuracy: 0.2724 - val_loss: 2.6840 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 32/400
# 1/1 [==============================] - 0s 307ms/step - loss: 2.2704 - accuracy: 0.2791 - val_loss: 2.6867 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 33/400
# 1/1 [==============================] - 0s 306ms/step - loss: 2.2452 - accuracy: 0.2954 - val_loss: 2.6895 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 34/400
# 1/1 [==============================] - 0s 310ms/step - loss: 2.2276 - accuracy: 0.3041 - val_loss: 2.6923 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 35/400
# 1/1 [==============================] - 0s 318ms/step - loss: 2.1712 - accuracy: 0.3163 - val_loss: 2.6952 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 36/400
# 1/1 [==============================] - 0s 239ms/step - loss: 2.1678 - accuracy: 0.3173 - val_loss: 2.6981 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 37/400
# 1/1 [==============================] - 0s 281ms/step - loss: 2.1139 - accuracy: 0.3240 - val_loss: 2.7011 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 38/400
# 1/1 [==============================] - 0s 268ms/step - loss: 2.1480 - accuracy: 0.3347 - val_loss: 2.7041 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 39/400
# 1/1 [==============================] - 0s 292ms/step - loss: 2.1069 - accuracy: 0.3500 - val_loss: 2.7072 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 40/400
# 1/1 [==============================] - 0s 277ms/step - loss: 2.0616 - accuracy: 0.3357 - val_loss: 2.7106 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 41/400
# 1/1 [==============================] - 0s 277ms/step - loss: 2.0237 - accuracy: 0.3505 - val_loss: 2.7139 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 42/400
# 1/1 [==============================] - 0s 273ms/step - loss: 2.0492 - accuracy: 0.3520 - val_loss: 2.7173 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 43/400
# 1/1 [==============================] - 0s 260ms/step - loss: 1.9931 - accuracy: 0.3699 - val_loss: 2.7208 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 44/400
# 1/1 [==============================] - 0s 286ms/step - loss: 1.9605 - accuracy: 0.3663 - val_loss: 2.7243 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 45/400
# 1/1 [==============================] - 0s 289ms/step - loss: 1.9412 - accuracy: 0.3755 - val_loss: 2.7278 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 46/400
# 1/1 [==============================] - 0s 293ms/step - loss: 1.9007 - accuracy: 0.3898 - val_loss: 2.7315 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 47/400
# 1/1 [==============================] - 0s 275ms/step - loss: 1.8998 - accuracy: 0.3923 - val_loss: 2.7351 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 48/400
# 1/1 [==============================] - 0s 290ms/step - loss: 1.9096 - accuracy: 0.3903 - val_loss: 2.7390 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 49/400
# 1/1 [==============================] - 0s 287ms/step - loss: 1.7977 - accuracy: 0.4138 - val_loss: 2.7430 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 50/400
# 1/1 [==============================] - 0s 291ms/step - loss: 1.8216 - accuracy: 0.4281 - val_loss: 2.7472 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 51/400
# 1/1 [==============================] - 0s 288ms/step - loss: 1.7640 - accuracy: 0.4439 - val_loss: 2.7515 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 52/400
# 1/1 [==============================] - 0s 282ms/step - loss: 1.7667 - accuracy: 0.4378 - val_loss: 2.7560 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 53/400
# 1/1 [==============================] - 0s 301ms/step - loss: 1.7367 - accuracy: 0.4316 - val_loss: 2.7605 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 54/400
# 1/1 [==============================] - 0s 279ms/step - loss: 1.7388 - accuracy: 0.4561 - val_loss: 2.7653 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 55/400
# 1/1 [==============================] - 0s 264ms/step - loss: 1.7140 - accuracy: 0.4526 - val_loss: 2.7702 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 56/400
# 1/1 [==============================] - 0s 276ms/step - loss: 1.6612 - accuracy: 0.4714 - val_loss: 2.7750 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 57/400
# 1/1 [==============================] - 0s 272ms/step - loss: 1.6723 - accuracy: 0.4730 - val_loss: 2.7800 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 58/400
# 1/1 [==============================] - 0s 280ms/step - loss: 1.6227 - accuracy: 0.4903 - val_loss: 2.7852 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 59/400
# 1/1 [==============================] - 0s 285ms/step - loss: 1.5951 - accuracy: 0.4893 - val_loss: 2.7904 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 60/400
# 1/1 [==============================] - 0s 293ms/step - loss: 1.5927 - accuracy: 0.4959 - val_loss: 2.7954 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 61/400
# 1/1 [==============================] - 0s 290ms/step - loss: 1.5971 - accuracy: 0.4847 - val_loss: 2.8003 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 62/400
# 1/1 [==============================] - 0s 294ms/step - loss: 1.5380 - accuracy: 0.5219 - val_loss: 2.8050 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 63/400
# 1/1 [==============================] - 0s 286ms/step - loss: 1.5258 - accuracy: 0.5235 - val_loss: 2.8097 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 64/400
# 1/1 [==============================] - 0s 292ms/step - loss: 1.4908 - accuracy: 0.5372 - val_loss: 2.8145 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 65/400
# 1/1 [==============================] - 0s 287ms/step - loss: 1.4946 - accuracy: 0.5423 - val_loss: 2.8191 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 66/400
# 1/1 [==============================] - 0s 295ms/step - loss: 1.4522 - accuracy: 0.5597 - val_loss: 2.8237 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 67/400
# 1/1 [==============================] - 0s 297ms/step - loss: 1.4275 - accuracy: 0.5663 - val_loss: 2.8283 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 68/400
# 1/1 [==============================] - 0s 293ms/step - loss: 1.4310 - accuracy: 0.5561 - val_loss: 2.8331 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 69/400
# 1/1 [==============================] - 0s 259ms/step - loss: 1.4121 - accuracy: 0.5750 - val_loss: 2.8380 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 70/400
# 1/1 [==============================] - 0s 309ms/step - loss: 1.3691 - accuracy: 0.5781 - val_loss: 2.8429 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 71/400
# 1/1 [==============================] - 0s 343ms/step - loss: 1.3690 - accuracy: 0.5699 - val_loss: 2.8478 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 72/400
# 1/1 [==============================] - 0s 314ms/step - loss: 1.3405 - accuracy: 0.5852 - val_loss: 2.8530 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 73/400
# 1/1 [==============================] - 0s 338ms/step - loss: 1.3171 - accuracy: 0.6015 - val_loss: 2.8582 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 74/400
# 1/1 [==============================] - 0s 306ms/step - loss: 1.3136 - accuracy: 0.5990 - val_loss: 2.8637 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 75/400
# 1/1 [==============================] - 0s 345ms/step - loss: 1.2982 - accuracy: 0.6102 - val_loss: 2.8696 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 76/400
# 1/1 [==============================] - 0s 311ms/step - loss: 1.2848 - accuracy: 0.6097 - val_loss: 2.8754 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 77/400
# 1/1 [==============================] - 0s 275ms/step - loss: 1.2799 - accuracy: 0.6143 - val_loss: 2.8817 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 78/400
# 1/1 [==============================] - 0s 283ms/step - loss: 1.2626 - accuracy: 0.6265 - val_loss: 2.8882 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 79/400
# 1/1 [==============================] - 0s 280ms/step - loss: 1.2579 - accuracy: 0.6255 - val_loss: 2.8948 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 80/400
# 1/1 [==============================] - 0s 258ms/step - loss: 1.2313 - accuracy: 0.6444 - val_loss: 2.9015 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 81/400
# 1/1 [==============================] - 0s 291ms/step - loss: 1.2274 - accuracy: 0.6408 - val_loss: 2.9081 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 82/400
# 1/1 [==============================] - 0s 269ms/step - loss: 1.1960 - accuracy: 0.6469 - val_loss: 2.9148 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 83/400
# 1/1 [==============================] - 0s 287ms/step - loss: 1.1943 - accuracy: 0.6531 - val_loss: 2.9213 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 84/400
# 1/1 [==============================] - 0s 263ms/step - loss: 1.1672 - accuracy: 0.6546 - val_loss: 2.9285 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 85/400
# 1/1 [==============================] - 0s 290ms/step - loss: 1.1779 - accuracy: 0.6531 - val_loss: 2.9360 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 86/400
# 1/1 [==============================] - 0s 242ms/step - loss: 1.1300 - accuracy: 0.6663 - val_loss: 2.9434 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 87/400
# 1/1 [==============================] - 0s 292ms/step - loss: 1.1217 - accuracy: 0.6770 - val_loss: 2.9507 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 88/400
# 1/1 [==============================] - 0s 259ms/step - loss: 1.1055 - accuracy: 0.6878 - val_loss: 2.9582 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 89/400
# 1/1 [==============================] - 0s 263ms/step - loss: 1.1133 - accuracy: 0.6770 - val_loss: 2.9652 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 90/400
# 1/1 [==============================] - 0s 294ms/step - loss: 1.0799 - accuracy: 0.6929 - val_loss: 2.9721 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 91/400
# 1/1 [==============================] - 0s 296ms/step - loss: 1.0938 - accuracy: 0.6847 - val_loss: 2.9789 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 92/400
# 1/1 [==============================] - 0s 279ms/step - loss: 1.0892 - accuracy: 0.7010 - val_loss: 2.9855 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 93/400
# 1/1 [==============================] - 0s 273ms/step - loss: 1.0629 - accuracy: 0.7041 - val_loss: 2.9923 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 94/400
# 1/1 [==============================] - 0s 262ms/step - loss: 1.0514 - accuracy: 0.7066 - val_loss: 2.9990 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 95/400
# 1/1 [==============================] - 0s 253ms/step - loss: 1.0348 - accuracy: 0.7082 - val_loss: 3.0055 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 96/400
# 1/1 [==============================] - 0s 289ms/step - loss: 1.0079 - accuracy: 0.7265 - val_loss: 3.0121 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 97/400
# 1/1 [==============================] - 0s 263ms/step - loss: 1.0259 - accuracy: 0.7184 - val_loss: 3.0190 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 98/400
# 1/1 [==============================] - 0s 271ms/step - loss: 1.0046 - accuracy: 0.7245 - val_loss: 3.0258 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 99/400
# 1/1 [==============================] - 0s 297ms/step - loss: 0.9745 - accuracy: 0.7240 - val_loss: 3.0336 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 100/400
# 1/1 [==============================] - 0s 262ms/step - loss: 0.9881 - accuracy: 0.7357 - val_loss: 3.0423 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 101/400
# 1/1 [==============================] - 0s 278ms/step - loss: 0.9794 - accuracy: 0.7337 - val_loss: 3.0508 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 102/400
# 1/1 [==============================] - 0s 257ms/step - loss: 0.9730 - accuracy: 0.7449 - val_loss: 3.0592 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 103/400
# 1/1 [==============================] - 0s 292ms/step - loss: 0.9589 - accuracy: 0.7321 - val_loss: 3.0677 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 104/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.9416 - accuracy: 0.7510 - val_loss: 3.0769 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 105/400
# 1/1 [==============================] - 0s 259ms/step - loss: 0.9276 - accuracy: 0.7587 - val_loss: 3.0865 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 106/400
# 1/1 [==============================] - 0s 268ms/step - loss: 0.9246 - accuracy: 0.7316 - val_loss: 3.0965 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 107/400
# 1/1 [==============================] - 0s 296ms/step - loss: 0.9247 - accuracy: 0.7582 - val_loss: 3.1064 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 108/400
# 1/1 [==============================] - 0s 264ms/step - loss: 0.9079 - accuracy: 0.7587 - val_loss: 3.1171 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 109/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.8938 - accuracy: 0.7673 - val_loss: 3.1268 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 110/400
# 1/1 [==============================] - 0s 295ms/step - loss: 0.8701 - accuracy: 0.7684 - val_loss: 3.1365 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 111/400
# 1/1 [==============================] - 0s 283ms/step - loss: 0.8743 - accuracy: 0.7719 - val_loss: 3.1455 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 112/400
# 1/1 [==============================] - 0s 285ms/step - loss: 0.8477 - accuracy: 0.7714 - val_loss: 3.1540 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 113/400
# 1/1 [==============================] - 0s 314ms/step - loss: 0.8860 - accuracy: 0.7714 - val_loss: 3.1618 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 114/400
# 1/1 [==============================] - 0s 325ms/step - loss: 0.8483 - accuracy: 0.7714 - val_loss: 3.1690 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 115/400
# 1/1 [==============================] - 0s 317ms/step - loss: 0.8641 - accuracy: 0.7760 - val_loss: 3.1770 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 116/400
# 1/1 [==============================] - 0s 307ms/step - loss: 0.8249 - accuracy: 0.7944 - val_loss: 3.1849 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 117/400
# 1/1 [==============================] - 0s 310ms/step - loss: 0.8541 - accuracy: 0.7837 - val_loss: 3.1926 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 118/400
# 1/1 [==============================] - 0s 315ms/step - loss: 0.8245 - accuracy: 0.7857 - val_loss: 3.1996 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 119/400
# 1/1 [==============================] - 0s 285ms/step - loss: 0.8235 - accuracy: 0.7867 - val_loss: 3.2055 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 120/400
# 1/1 [==============================] - 0s 291ms/step - loss: 0.7796 - accuracy: 0.8031 - val_loss: 3.2118 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 121/400
# 1/1 [==============================] - 0s 273ms/step - loss: 0.7973 - accuracy: 0.7903 - val_loss: 3.2179 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 122/400
# 1/1 [==============================] - 0s 289ms/step - loss: 0.7911 - accuracy: 0.8036 - val_loss: 3.2256 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 123/400
# 1/1 [==============================] - 0s 261ms/step - loss: 0.7715 - accuracy: 0.8015 - val_loss: 3.2327 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 124/400
# 1/1 [==============================] - 0s 272ms/step - loss: 0.7895 - accuracy: 0.8000 - val_loss: 3.2379 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 125/400
# 1/1 [==============================] - 0s 299ms/step - loss: 0.7640 - accuracy: 0.8117 - val_loss: 3.2436 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 126/400
# 1/1 [==============================] - 0s 292ms/step - loss: 0.7731 - accuracy: 0.8010 - val_loss: 3.2499 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 127/400
# 1/1 [==============================] - 0s 272ms/step - loss: 0.7525 - accuracy: 0.8148 - val_loss: 3.2563 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 128/400
# 1/1 [==============================] - 0s 296ms/step - loss: 0.7542 - accuracy: 0.8056 - val_loss: 3.2632 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 129/400
# 1/1 [==============================] - 0s 275ms/step - loss: 0.7590 - accuracy: 0.8026 - val_loss: 3.2695 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 130/400
# 1/1 [==============================] - 0s 263ms/step - loss: 0.7386 - accuracy: 0.8122 - val_loss: 3.2752 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 131/400
# 1/1 [==============================] - 0s 262ms/step - loss: 0.7285 - accuracy: 0.8102 - val_loss: 3.2813 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 132/400
# 1/1 [==============================] - 0s 253ms/step - loss: 0.7035 - accuracy: 0.8306 - val_loss: 3.2876 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 133/400
# 1/1 [==============================] - 0s 269ms/step - loss: 0.7306 - accuracy: 0.8138 - val_loss: 3.2929 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 134/400
# 1/1 [==============================] - 0s 297ms/step - loss: 0.6948 - accuracy: 0.8296 - val_loss: 3.2983 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 135/400
# 1/1 [==============================] - 0s 266ms/step - loss: 0.7275 - accuracy: 0.8179 - val_loss: 3.3038 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 136/400
# 1/1 [==============================] - 0s 276ms/step - loss: 0.7100 - accuracy: 0.8240 - val_loss: 3.3112 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 137/400
# 1/1 [==============================] - 0s 296ms/step - loss: 0.7086 - accuracy: 0.8204 - val_loss: 3.3197 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 138/400
# 1/1 [==============================] - 0s 262ms/step - loss: 0.6906 - accuracy: 0.8342 - val_loss: 3.3295 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 139/400
# 1/1 [==============================] - 0s 258ms/step - loss: 0.7055 - accuracy: 0.8316 - val_loss: 3.3395 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 140/400
# 1/1 [==============================] - 0s 294ms/step - loss: 0.6699 - accuracy: 0.8423 - val_loss: 3.3491 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 141/400
# 1/1 [==============================] - 0s 266ms/step - loss: 0.6659 - accuracy: 0.8398 - val_loss: 3.3581 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 142/400
# 1/1 [==============================] - 0s 289ms/step - loss: 0.6810 - accuracy: 0.8255 - val_loss: 3.3657 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 143/400
# 1/1 [==============================] - 0s 290ms/step - loss: 0.6658 - accuracy: 0.8434 - val_loss: 3.3725 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 144/400
# 1/1 [==============================] - 0s 256ms/step - loss: 0.6650 - accuracy: 0.8265 - val_loss: 3.3793 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 145/400
# 1/1 [==============================] - 0s 297ms/step - loss: 0.6578 - accuracy: 0.8352 - val_loss: 3.3864 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 146/400
# 1/1 [==============================] - 0s 239ms/step - loss: 0.6374 - accuracy: 0.8592 - val_loss: 3.3929 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 147/400
# 1/1 [==============================] - 0s 294ms/step - loss: 0.6367 - accuracy: 0.8592 - val_loss: 3.3986 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 148/400
# 1/1 [==============================] - 0s 291ms/step - loss: 0.6548 - accuracy: 0.8439 - val_loss: 3.4054 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 149/400
# 1/1 [==============================] - 0s 296ms/step - loss: 0.6224 - accuracy: 0.8495 - val_loss: 3.4123 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 150/400
# 1/1 [==============================] - 0s 291ms/step - loss: 0.6369 - accuracy: 0.8393 - val_loss: 3.4197 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 151/400
# 1/1 [==============================] - 0s 280ms/step - loss: 0.6060 - accuracy: 0.8582 - val_loss: 3.4262 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 152/400
# 1/1 [==============================] - 0s 296ms/step - loss: 0.6275 - accuracy: 0.8587 - val_loss: 3.4309 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 153/400
# 1/1 [==============================] - 0s 252ms/step - loss: 0.6287 - accuracy: 0.8571 - val_loss: 3.4339 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 154/400
# 1/1 [==============================] - 0s 265ms/step - loss: 0.5875 - accuracy: 0.8704 - val_loss: 3.4386 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 155/400
# 1/1 [==============================] - 0s 320ms/step - loss: 0.6219 - accuracy: 0.8520 - val_loss: 3.4434 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 156/400
# 1/1 [==============================] - 0s 294ms/step - loss: 0.6179 - accuracy: 0.8587 - val_loss: 3.4474 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 157/400
# 1/1 [==============================] - 0s 327ms/step - loss: 0.6002 - accuracy: 0.8597 - val_loss: 3.4506 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 158/400
# 1/1 [==============================] - 0s 347ms/step - loss: 0.5847 - accuracy: 0.8719 - val_loss: 3.4539 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 159/400
# 1/1 [==============================] - 0s 321ms/step - loss: 0.5938 - accuracy: 0.8673 - val_loss: 3.4577 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 160/400
# 1/1 [==============================] - 0s 317ms/step - loss: 0.5967 - accuracy: 0.8551 - val_loss: 3.4625 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 161/400
# 1/1 [==============================] - 0s 302ms/step - loss: 0.5892 - accuracy: 0.8694 - val_loss: 3.4655 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 162/400
# 1/1 [==============================] - 0s 283ms/step - loss: 0.5657 - accuracy: 0.8735 - val_loss: 3.4693 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 163/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.5634 - accuracy: 0.8786 - val_loss: 3.4736 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 164/400
# 1/1 [==============================] - 0s 249ms/step - loss: 0.5713 - accuracy: 0.8699 - val_loss: 3.4749 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 165/400
# 1/1 [==============================] - 0s 270ms/step - loss: 0.5533 - accuracy: 0.8786 - val_loss: 3.4769 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 166/400
# 1/1 [==============================] - 0s 314ms/step - loss: 0.5518 - accuracy: 0.8730 - val_loss: 3.4781 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 167/400
# 1/1 [==============================] - 0s 297ms/step - loss: 0.5340 - accuracy: 0.8872 - val_loss: 3.4781 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 168/400
# 1/1 [==============================] - 0s 295ms/step - loss: 0.5525 - accuracy: 0.8760 - val_loss: 3.4770 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 169/400
# 1/1 [==============================] - 0s 268ms/step - loss: 0.5356 - accuracy: 0.8821 - val_loss: 3.4734 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 170/400
# 1/1 [==============================] - 0s 261ms/step - loss: 0.5371 - accuracy: 0.8755 - val_loss: 3.4699 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 171/400
# 1/1 [==============================] - 0s 290ms/step - loss: 0.5311 - accuracy: 0.8821 - val_loss: 3.4653 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 172/400
# 1/1 [==============================] - 0s 245ms/step - loss: 0.5376 - accuracy: 0.8801 - val_loss: 3.4591 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 173/400
# 1/1 [==============================] - 0s 246ms/step - loss: 0.5267 - accuracy: 0.8857 - val_loss: 3.4539 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 174/400
# 1/1 [==============================] - 0s 293ms/step - loss: 0.5389 - accuracy: 0.8857 - val_loss: 3.4507 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 175/400
# 1/1 [==============================] - 0s 289ms/step - loss: 0.4988 - accuracy: 0.8934 - val_loss: 3.4488 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 176/400
# 1/1 [==============================] - 0s 269ms/step - loss: 0.5156 - accuracy: 0.8872 - val_loss: 3.4462 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 177/400
# 1/1 [==============================] - 0s 259ms/step - loss: 0.5127 - accuracy: 0.8929 - val_loss: 3.4458 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 178/400
# 1/1 [==============================] - 0s 259ms/step - loss: 0.5239 - accuracy: 0.8760 - val_loss: 3.4449 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 179/400
# 1/1 [==============================] - 0s 300ms/step - loss: 0.5159 - accuracy: 0.8827 - val_loss: 3.4454 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 180/400
# 1/1 [==============================] - 0s 292ms/step - loss: 0.5084 - accuracy: 0.8949 - val_loss: 3.4455 - val_accuracy: 0.0607 - lr: 1.0000e-04
# Epoch 181/400
# 1/1 [==============================] - 0s 291ms/step - loss: 0.5073 - accuracy: 0.8888 - val_loss: 3.4424 - val_accuracy: 0.0607 - lr: 5.0000e-05
# Epoch 182/400
# 1/1 [==============================] - 0s 277ms/step - loss: 0.5148 - accuracy: 0.8816 - val_loss: 3.4390 - val_accuracy: 0.0607 - lr: 5.0000e-05
# Epoch 183/400
# 1/1 [==============================] - 0s 287ms/step - loss: 0.4771 - accuracy: 0.8980 - val_loss: 3.4366 - val_accuracy: 0.0607 - lr: 5.0000e-05
# Epoch 184/400
# 1/1 [==============================] - 0s 312ms/step - loss: 0.4978 - accuracy: 0.8898 - val_loss: 3.4349 - val_accuracy: 0.0607 - lr: 5.0000e-05
# Epoch 185/400
# 1/1 [==============================] - 0s 296ms/step - loss: 0.4997 - accuracy: 0.8883 - val_loss: 3.4328 - val_accuracy: 0.0607 - lr: 5.0000e-05
# Epoch 186/400
# 1/1 [==============================] - 0s 298ms/step - loss: 0.4928 - accuracy: 0.8903 - val_loss: 3.4319 - val_accuracy: 0.0607 - lr: 5.0000e-05
# Epoch 187/400
# 1/1 [==============================] - 0s 297ms/step - loss: 0.4904 - accuracy: 0.8913 - val_loss: 3.4300 - val_accuracy: 0.0607 - lr: 5.0000e-05
# Epoch 188/400
# 1/1 [==============================] - 0s 269ms/step - loss: 0.4847 - accuracy: 0.8980 - val_loss: 3.4274 - val_accuracy: 0.0607 - lr: 5.0000e-05
# Epoch 189/400
# 1/1 [==============================] - 0s 299ms/step - loss: 0.5002 - accuracy: 0.8827 - val_loss: 3.4248 - val_accuracy: 0.0607 - lr: 5.0000e-05
# Epoch 190/400
# 1/1 [==============================] - 0s 255ms/step - loss: 0.5066 - accuracy: 0.8893 - val_loss: 3.4214 - val_accuracy: 0.0607 - lr: 2.5000e-05
# Epoch 191/400
# 1/1 [==============================] - 0s 285ms/step - loss: 0.4873 - accuracy: 0.8959 - val_loss: 3.4179 - val_accuracy: 0.0607 - lr: 2.5000e-05
# Epoch 192/400
# 1/1 [==============================] - 0s 264ms/step - loss: 0.4933 - accuracy: 0.8934 - val_loss: 3.4139 - val_accuracy: 0.0607 - lr: 2.5000e-05
# Epoch 193/400
# 1/1 [==============================] - 0s 298ms/step - loss: 0.4914 - accuracy: 0.8974 - val_loss: 3.4103 - val_accuracy: 0.0631 - lr: 2.5000e-05
# Epoch 194/400
# 1/1 [==============================] - 0s 296ms/step - loss: 0.4741 - accuracy: 0.8974 - val_loss: 3.4062 - val_accuracy: 0.0643 - lr: 2.5000e-05
# Epoch 195/400
# 1/1 [==============================] - 0s 297ms/step - loss: 0.4837 - accuracy: 0.8918 - val_loss: 3.4027 - val_accuracy: 0.0643 - lr: 2.5000e-05
# Epoch 196/400
# 1/1 [==============================] - 0s 293ms/step - loss: 0.4798 - accuracy: 0.9026 - val_loss: 3.3993 - val_accuracy: 0.0655 - lr: 2.5000e-05
# Epoch 197/400
# 1/1 [==============================] - 0s 319ms/step - loss: 0.4899 - accuracy: 0.9000 - val_loss: 3.3956 - val_accuracy: 0.0655 - lr: 2.5000e-05
# Epoch 198/400
# 1/1 [==============================] - 0s 309ms/step - loss: 0.5042 - accuracy: 0.8959 - val_loss: 3.3919 - val_accuracy: 0.0667 - lr: 2.5000e-05
# Epoch 199/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.4816 - accuracy: 0.8913 - val_loss: 3.3879 - val_accuracy: 0.0667 - lr: 2.5000e-05
# Epoch 200/400
# 1/1 [==============================] - 0s 302ms/step - loss: 0.4622 - accuracy: 0.8974 - val_loss: 3.3832 - val_accuracy: 0.0679 - lr: 1.2500e-05
# Epoch 201/400
# 1/1 [==============================] - 0s 289ms/step - loss: 0.4854 - accuracy: 0.8959 - val_loss: 3.3792 - val_accuracy: 0.0679 - lr: 1.2500e-05
# Epoch 202/400
# 1/1 [==============================] - 0s 305ms/step - loss: 0.4939 - accuracy: 0.8995 - val_loss: 3.3750 - val_accuracy: 0.0679 - lr: 1.2500e-05
# Epoch 203/400
# 1/1 [==============================] - 0s 280ms/step - loss: 0.4849 - accuracy: 0.8944 - val_loss: 3.3700 - val_accuracy: 0.0679 - lr: 1.2500e-05
# Epoch 204/400
# 1/1 [==============================] - 0s 280ms/step - loss: 0.4793 - accuracy: 0.8913 - val_loss: 3.3649 - val_accuracy: 0.0679 - lr: 1.2500e-05
# Epoch 205/400
# 1/1 [==============================] - 0s 297ms/step - loss: 0.4767 - accuracy: 0.9041 - val_loss: 3.3598 - val_accuracy: 0.0679 - lr: 1.2500e-05
# Epoch 206/400
# 1/1 [==============================] - 0s 249ms/step - loss: 0.4780 - accuracy: 0.8985 - val_loss: 3.3542 - val_accuracy: 0.0690 - lr: 1.2500e-05
# Epoch 207/400
# 1/1 [==============================] - 0s 271ms/step - loss: 0.4685 - accuracy: 0.9026 - val_loss: 3.3492 - val_accuracy: 0.0690 - lr: 1.2500e-05
# Epoch 208/400
# 1/1 [==============================] - 0s 293ms/step - loss: 0.4764 - accuracy: 0.9036 - val_loss: 3.3441 - val_accuracy: 0.0690 - lr: 1.2500e-05
# Epoch 209/400
# 1/1 [==============================] - 0s 257ms/step - loss: 0.4732 - accuracy: 0.8974 - val_loss: 3.3385 - val_accuracy: 0.0714 - lr: 6.2500e-06
# Epoch 210/400
# 1/1 [==============================] - 0s 263ms/step - loss: 0.4747 - accuracy: 0.9051 - val_loss: 3.3331 - val_accuracy: 0.0714 - lr: 6.2500e-06
# Epoch 211/400
# 1/1 [==============================] - 0s 249ms/step - loss: 0.4876 - accuracy: 0.8964 - val_loss: 3.3276 - val_accuracy: 0.0714 - lr: 6.2500e-06
# Epoch 212/400
# 1/1 [==============================] - 0s 267ms/step - loss: 0.4924 - accuracy: 0.8883 - val_loss: 3.3226 - val_accuracy: 0.0714 - lr: 6.2500e-06
# Epoch 213/400
# 1/1 [==============================] - 0s 266ms/step - loss: 0.4690 - accuracy: 0.9000 - val_loss: 3.3169 - val_accuracy: 0.0714 - lr: 6.2500e-06
# Epoch 214/400
# 1/1 [==============================] - 0s 298ms/step - loss: 0.4776 - accuracy: 0.8923 - val_loss: 3.3110 - val_accuracy: 0.0714 - lr: 6.2500e-06
# Epoch 215/400
# 1/1 [==============================] - 0s 286ms/step - loss: 0.4721 - accuracy: 0.9000 - val_loss: 3.3052 - val_accuracy: 0.0714 - lr: 6.2500e-06
# Epoch 216/400
# 1/1 [==============================] - 0s 279ms/step - loss: 0.4768 - accuracy: 0.8964 - val_loss: 3.2994 - val_accuracy: 0.0714 - lr: 6.2500e-06
# Epoch 217/400
# 1/1 [==============================] - 0s 269ms/step - loss: 0.4670 - accuracy: 0.8980 - val_loss: 3.2938 - val_accuracy: 0.0714 - lr: 6.2500e-06
# Epoch 218/400
# 1/1 [==============================] - 0s 295ms/step - loss: 0.4751 - accuracy: 0.8939 - val_loss: 3.2881 - val_accuracy: 0.0714 - lr: 5.0000e-06
# Epoch 219/400
# 1/1 [==============================] - 0s 287ms/step - loss: 0.4702 - accuracy: 0.9046 - val_loss: 3.2823 - val_accuracy: 0.0726 - lr: 5.0000e-06
# Epoch 220/400
# 1/1 [==============================] - 0s 269ms/step - loss: 0.4753 - accuracy: 0.9010 - val_loss: 3.2762 - val_accuracy: 0.0738 - lr: 5.0000e-06
# Epoch 221/400
# 1/1 [==============================] - 0s 291ms/step - loss: 0.4756 - accuracy: 0.8964 - val_loss: 3.2704 - val_accuracy: 0.0738 - lr: 5.0000e-06
# Epoch 222/400
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4762 - accuracy: 0.8954 - val_loss: 3.2648 - val_accuracy: 0.0738 - lr: 5.0000e-06
# Epoch 223/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.4581 - accuracy: 0.8990 - val_loss: 3.2590 - val_accuracy: 0.0738 - lr: 5.0000e-06
# Epoch 224/400
# 1/1 [==============================] - 0s 292ms/step - loss: 0.4723 - accuracy: 0.9000 - val_loss: 3.2532 - val_accuracy: 0.0750 - lr: 5.0000e-06
# Epoch 225/400
# 1/1 [==============================] - 0s 300ms/step - loss: 0.4778 - accuracy: 0.8974 - val_loss: 3.2472 - val_accuracy: 0.0750 - lr: 5.0000e-06
# Epoch 226/400
# 1/1 [==============================] - 0s 276ms/step - loss: 0.4872 - accuracy: 0.8842 - val_loss: 3.2413 - val_accuracy: 0.0762 - lr: 5.0000e-06
# Epoch 227/400
# 1/1 [==============================] - 0s 293ms/step - loss: 0.4629 - accuracy: 0.8939 - val_loss: 3.2352 - val_accuracy: 0.0762 - lr: 5.0000e-06
# Epoch 228/400
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4660 - accuracy: 0.8990 - val_loss: 3.2292 - val_accuracy: 0.0762 - lr: 5.0000e-06
# Epoch 229/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.4764 - accuracy: 0.8959 - val_loss: 3.2235 - val_accuracy: 0.0762 - lr: 5.0000e-06
# Epoch 230/400
# 1/1 [==============================] - 0s 268ms/step - loss: 0.4520 - accuracy: 0.9061 - val_loss: 3.2177 - val_accuracy: 0.0762 - lr: 5.0000e-06
# Epoch 231/400
# 1/1 [==============================] - 0s 276ms/step - loss: 0.4720 - accuracy: 0.9031 - val_loss: 3.2118 - val_accuracy: 0.0762 - lr: 5.0000e-06
# Epoch 232/400
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4814 - accuracy: 0.8980 - val_loss: 3.2063 - val_accuracy: 0.0762 - lr: 5.0000e-06
# Epoch 233/400
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4758 - accuracy: 0.9056 - val_loss: 3.2000 - val_accuracy: 0.0774 - lr: 5.0000e-06
# Epoch 234/400
# 1/1 [==============================] - 0s 281ms/step - loss: 0.4819 - accuracy: 0.8990 - val_loss: 3.1942 - val_accuracy: 0.0774 - lr: 5.0000e-06
# Epoch 235/400
# 1/1 [==============================] - 0s 266ms/step - loss: 0.4620 - accuracy: 0.9122 - val_loss: 3.1880 - val_accuracy: 0.0786 - lr: 5.0000e-06
# Epoch 236/400
# 1/1 [==============================] - 0s 273ms/step - loss: 0.4675 - accuracy: 0.9036 - val_loss: 3.1818 - val_accuracy: 0.0786 - lr: 5.0000e-06
# Epoch 237/400
# 1/1 [==============================] - 0s 308ms/step - loss: 0.4732 - accuracy: 0.8959 - val_loss: 3.1756 - val_accuracy: 0.0786 - lr: 5.0000e-06
# Epoch 238/400
# 1/1 [==============================] - 0s 316ms/step - loss: 0.4603 - accuracy: 0.8969 - val_loss: 3.1695 - val_accuracy: 0.0786 - lr: 5.0000e-06
# Epoch 239/400
# 1/1 [==============================] - 0s 342ms/step - loss: 0.4549 - accuracy: 0.9066 - val_loss: 3.1633 - val_accuracy: 0.0821 - lr: 5.0000e-06
# Epoch 240/400
# 1/1 [==============================] - 0s 323ms/step - loss: 0.4769 - accuracy: 0.8903 - val_loss: 3.1572 - val_accuracy: 0.0821 - lr: 5.0000e-06
# Epoch 241/400
# 1/1 [==============================] - 0s 312ms/step - loss: 0.4593 - accuracy: 0.9051 - val_loss: 3.1506 - val_accuracy: 0.0845 - lr: 5.0000e-06
# Epoch 242/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.4629 - accuracy: 0.9005 - val_loss: 3.1439 - val_accuracy: 0.0845 - lr: 5.0000e-06
# Epoch 243/400
# 1/1 [==============================] - 0s 307ms/step - loss: 0.4546 - accuracy: 0.9128 - val_loss: 3.1374 - val_accuracy: 0.0845 - lr: 5.0000e-06
# Epoch 244/400
# 1/1 [==============================] - 0s 340ms/step - loss: 0.4773 - accuracy: 0.8934 - val_loss: 3.1304 - val_accuracy: 0.0845 - lr: 5.0000e-06
# Epoch 245/400
# 1/1 [==============================] - 0s 294ms/step - loss: 0.4725 - accuracy: 0.8995 - val_loss: 3.1234 - val_accuracy: 0.0845 - lr: 5.0000e-06
# Epoch 246/400
# 1/1 [==============================] - 0s 272ms/step - loss: 0.4646 - accuracy: 0.9041 - val_loss: 3.1168 - val_accuracy: 0.0857 - lr: 5.0000e-06
# Epoch 247/400
# 1/1 [==============================] - 0s 300ms/step - loss: 0.4482 - accuracy: 0.9061 - val_loss: 3.1101 - val_accuracy: 0.0869 - lr: 5.0000e-06
# Epoch 248/400
# 1/1 [==============================] - 0s 268ms/step - loss: 0.4597 - accuracy: 0.9015 - val_loss: 3.1038 - val_accuracy: 0.0881 - lr: 5.0000e-06
# Epoch 249/400
# 1/1 [==============================] - 0s 302ms/step - loss: 0.4600 - accuracy: 0.9036 - val_loss: 3.0974 - val_accuracy: 0.0881 - lr: 5.0000e-06
# Epoch 250/400
# 1/1 [==============================] - 0s 243ms/step - loss: 0.4843 - accuracy: 0.8923 - val_loss: 3.0907 - val_accuracy: 0.0893 - lr: 5.0000e-06
# Epoch 251/400
# 1/1 [==============================] - 0s 289ms/step - loss: 0.4748 - accuracy: 0.9010 - val_loss: 3.0837 - val_accuracy: 0.0893 - lr: 5.0000e-06
# Epoch 252/400
# 1/1 [==============================] - 0s 258ms/step - loss: 0.4801 - accuracy: 0.8995 - val_loss: 3.0768 - val_accuracy: 0.0893 - lr: 5.0000e-06
# Epoch 253/400
# 1/1 [==============================] - 0s 261ms/step - loss: 0.4614 - accuracy: 0.9061 - val_loss: 3.0698 - val_accuracy: 0.0893 - lr: 5.0000e-06
# Epoch 254/400
# 1/1 [==============================] - 0s 298ms/step - loss: 0.4757 - accuracy: 0.8995 - val_loss: 3.0633 - val_accuracy: 0.0893 - lr: 5.0000e-06
# Epoch 255/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.4937 - accuracy: 0.8934 - val_loss: 3.0566 - val_accuracy: 0.0929 - lr: 5.0000e-06
# Epoch 256/400
# 1/1 [==============================] - 0s 297ms/step - loss: 0.4750 - accuracy: 0.9046 - val_loss: 3.0497 - val_accuracy: 0.0929 - lr: 5.0000e-06
# Epoch 257/400
# 1/1 [==============================] - 0s 260ms/step - loss: 0.4637 - accuracy: 0.8990 - val_loss: 3.0424 - val_accuracy: 0.0940 - lr: 5.0000e-06
# Epoch 258/400
# 1/1 [==============================] - 0s 277ms/step - loss: 0.4783 - accuracy: 0.9000 - val_loss: 3.0352 - val_accuracy: 0.0940 - lr: 5.0000e-06
# Epoch 259/400
# 1/1 [==============================] - 0s 302ms/step - loss: 0.4599 - accuracy: 0.8934 - val_loss: 3.0280 - val_accuracy: 0.0952 - lr: 5.0000e-06
# Epoch 260/400
# 1/1 [==============================] - 0s 271ms/step - loss: 0.4827 - accuracy: 0.8954 - val_loss: 3.0210 - val_accuracy: 0.0976 - lr: 5.0000e-06
# Epoch 261/400
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4666 - accuracy: 0.8995 - val_loss: 3.0137 - val_accuracy: 0.0988 - lr: 5.0000e-06
# Epoch 262/400
# 1/1 [==============================] - 0s 291ms/step - loss: 0.4617 - accuracy: 0.9051 - val_loss: 3.0067 - val_accuracy: 0.1024 - lr: 5.0000e-06
# Epoch 263/400
# 1/1 [==============================] - 0s 268ms/step - loss: 0.4704 - accuracy: 0.8990 - val_loss: 2.9992 - val_accuracy: 0.1024 - lr: 5.0000e-06
# Epoch 264/400
# 1/1 [==============================] - 0s 306ms/step - loss: 0.4802 - accuracy: 0.8964 - val_loss: 2.9918 - val_accuracy: 0.1036 - lr: 5.0000e-06
# Epoch 265/400
# 1/1 [==============================] - 0s 305ms/step - loss: 0.4716 - accuracy: 0.8954 - val_loss: 2.9842 - val_accuracy: 0.1036 - lr: 5.0000e-06
# Epoch 266/400
# 1/1 [==============================] - 0s 273ms/step - loss: 0.4563 - accuracy: 0.9051 - val_loss: 2.9763 - val_accuracy: 0.1071 - lr: 5.0000e-06
# Epoch 267/400
# 1/1 [==============================] - 0s 295ms/step - loss: 0.4678 - accuracy: 0.8969 - val_loss: 2.9683 - val_accuracy: 0.1071 - lr: 5.0000e-06
# Epoch 268/400
# 1/1 [==============================] - 0s 299ms/step - loss: 0.4533 - accuracy: 0.9107 - val_loss: 2.9605 - val_accuracy: 0.1071 - lr: 5.0000e-06
# Epoch 269/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.4650 - accuracy: 0.8964 - val_loss: 2.9525 - val_accuracy: 0.1071 - lr: 5.0000e-06
# Epoch 270/400
# 1/1 [==============================] - 0s 284ms/step - loss: 0.4858 - accuracy: 0.8949 - val_loss: 2.9447 - val_accuracy: 0.1083 - lr: 5.0000e-06
# Epoch 271/400
# 1/1 [==============================] - 0s 279ms/step - loss: 0.4724 - accuracy: 0.9031 - val_loss: 2.9367 - val_accuracy: 0.1095 - lr: 5.0000e-06
# Epoch 272/400
# 1/1 [==============================] - 0s 283ms/step - loss: 0.4743 - accuracy: 0.8990 - val_loss: 2.9285 - val_accuracy: 0.1119 - lr: 5.0000e-06
# Epoch 273/400
# 1/1 [==============================] - 0s 298ms/step - loss: 0.4725 - accuracy: 0.8985 - val_loss: 2.9207 - val_accuracy: 0.1131 - lr: 5.0000e-06
# Epoch 274/400
# 1/1 [==============================] - 0s 278ms/step - loss: 0.4541 - accuracy: 0.9041 - val_loss: 2.9126 - val_accuracy: 0.1179 - lr: 5.0000e-06
# Epoch 275/400
# 1/1 [==============================] - 0s 281ms/step - loss: 0.4758 - accuracy: 0.8974 - val_loss: 2.9048 - val_accuracy: 0.1190 - lr: 5.0000e-06
# Epoch 276/400
# 1/1 [==============================] - 0s 277ms/step - loss: 0.4591 - accuracy: 0.9082 - val_loss: 2.8969 - val_accuracy: 0.1214 - lr: 5.0000e-06
# Epoch 277/400
# 1/1 [==============================] - 0s 280ms/step - loss: 0.4495 - accuracy: 0.9031 - val_loss: 2.8887 - val_accuracy: 0.1226 - lr: 5.0000e-06
# Epoch 278/400
# 1/1 [==============================] - 0s 269ms/step - loss: 0.4630 - accuracy: 0.9041 - val_loss: 2.8810 - val_accuracy: 0.1238 - lr: 5.0000e-06
# Epoch 279/400
# 1/1 [==============================] - 0s 287ms/step - loss: 0.4617 - accuracy: 0.9005 - val_loss: 2.8732 - val_accuracy: 0.1238 - lr: 5.0000e-06
# Epoch 280/400
# 1/1 [==============================] - 0s 295ms/step - loss: 0.4505 - accuracy: 0.9046 - val_loss: 2.8647 - val_accuracy: 0.1250 - lr: 5.0000e-06
# Epoch 281/400
# 1/1 [==============================] - 0s 336ms/step - loss: 0.4787 - accuracy: 0.9051 - val_loss: 2.8568 - val_accuracy: 0.1250 - lr: 5.0000e-06
# Epoch 282/400
# 1/1 [==============================] - 0s 359ms/step - loss: 0.4613 - accuracy: 0.9051 - val_loss: 2.8492 - val_accuracy: 0.1262 - lr: 5.0000e-06
# Epoch 283/400
# 1/1 [==============================] - 0s 306ms/step - loss: 0.4706 - accuracy: 0.9015 - val_loss: 2.8413 - val_accuracy: 0.1262 - lr: 5.0000e-06
# Epoch 284/400
# 1/1 [==============================] - 0s 321ms/step - loss: 0.4540 - accuracy: 0.9020 - val_loss: 2.8333 - val_accuracy: 0.1262 - lr: 5.0000e-06
# Epoch 285/400
# 1/1 [==============================] - 0s 349ms/step - loss: 0.4634 - accuracy: 0.9112 - val_loss: 2.8255 - val_accuracy: 0.1262 - lr: 5.0000e-06
# Epoch 286/400
# 1/1 [==============================] - 0s 328ms/step - loss: 0.4717 - accuracy: 0.8939 - val_loss: 2.8177 - val_accuracy: 0.1262 - lr: 5.0000e-06
# Epoch 287/400
# 1/1 [==============================] - 0s 298ms/step - loss: 0.4675 - accuracy: 0.8995 - val_loss: 2.8097 - val_accuracy: 0.1274 - lr: 5.0000e-06
# Epoch 288/400
# 1/1 [==============================] - 0s 301ms/step - loss: 0.4877 - accuracy: 0.8980 - val_loss: 2.8014 - val_accuracy: 0.1310 - lr: 5.0000e-06
# Epoch 289/400
# 1/1 [==============================] - 0s 295ms/step - loss: 0.4639 - accuracy: 0.9041 - val_loss: 2.7934 - val_accuracy: 0.1310 - lr: 5.0000e-06
# Epoch 290/400
# 1/1 [==============================] - 0s 268ms/step - loss: 0.4522 - accuracy: 0.9046 - val_loss: 2.7850 - val_accuracy: 0.1321 - lr: 5.0000e-06
# Epoch 291/400
# 1/1 [==============================] - 0s 252ms/step - loss: 0.4573 - accuracy: 0.9041 - val_loss: 2.7767 - val_accuracy: 0.1333 - lr: 5.0000e-06
# Epoch 292/400
# 1/1 [==============================] - 0s 289ms/step - loss: 0.4725 - accuracy: 0.8990 - val_loss: 2.7684 - val_accuracy: 0.1357 - lr: 5.0000e-06
# Epoch 293/400
# 1/1 [==============================] - 0s 265ms/step - loss: 0.4690 - accuracy: 0.8995 - val_loss: 2.7599 - val_accuracy: 0.1393 - lr: 5.0000e-06
# Epoch 294/400
# 1/1 [==============================] - 0s 251ms/step - loss: 0.4641 - accuracy: 0.9026 - val_loss: 2.7513 - val_accuracy: 0.1405 - lr: 5.0000e-06
# Epoch 295/400
# 1/1 [==============================] - 0s 282ms/step - loss: 0.4576 - accuracy: 0.9051 - val_loss: 2.7432 - val_accuracy: 0.1429 - lr: 5.0000e-06
# Epoch 296/400
# 1/1 [==============================] - 0s 287ms/step - loss: 0.4678 - accuracy: 0.9036 - val_loss: 2.7346 - val_accuracy: 0.1440 - lr: 5.0000e-06
# Epoch 297/400
# 1/1 [==============================] - 0s 288ms/step - loss: 0.4662 - accuracy: 0.8995 - val_loss: 2.7262 - val_accuracy: 0.1476 - lr: 5.0000e-06
# Epoch 298/400
# 1/1 [==============================] - 0s 269ms/step - loss: 0.4660 - accuracy: 0.9010 - val_loss: 2.7176 - val_accuracy: 0.1476 - lr: 5.0000e-06
# Epoch 299/400
# 1/1 [==============================] - 0s 256ms/step - loss: 0.4514 - accuracy: 0.9031 - val_loss: 2.7093 - val_accuracy: 0.1476 - lr: 5.0000e-06
# Epoch 300/400
# 1/1 [==============================] - 0s 301ms/step - loss: 0.4723 - accuracy: 0.9036 - val_loss: 2.7009 - val_accuracy: 0.1500 - lr: 5.0000e-06
# Epoch 301/400
# ...
# Epoch 401/500
# 1/1 [==============================] - 0s 275ms/step - loss: 0.1766 - accuracy: 0.9796 - val_loss: 0.1959 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 402/500
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1745 - accuracy: 0.9801 - val_loss: 0.1959 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 403/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1728 - accuracy: 0.9821 - val_loss: 0.1958 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 404/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1822 - accuracy: 0.9791 - val_loss: 0.1958 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 405/500
# 1/1 [==============================] - 0s 261ms/step - loss: 0.1778 - accuracy: 0.9806 - val_loss: 0.1957 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 406/500
# 1/1 [==============================] - 0s 310ms/step - loss: 0.1905 - accuracy: 0.9730 - val_loss: 0.1956 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 407/500
# 1/1 [==============================] - 0s 324ms/step - loss: 0.1776 - accuracy: 0.9801 - val_loss: 0.1955 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 408/500
# 1/1 [==============================] - 0s 250ms/step - loss: 0.1710 - accuracy: 0.9801 - val_loss: 0.1954 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 409/500
# 1/1 [==============================] - 0s 305ms/step - loss: 0.1898 - accuracy: 0.9750 - val_loss: 0.1954 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 410/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.1739 - accuracy: 0.9796 - val_loss: 0.1954 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 411/500
# 1/1 [==============================] - 0s 303ms/step - loss: 0.1766 - accuracy: 0.9765 - val_loss: 0.1953 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 412/500
# 1/1 [==============================] - 0s 307ms/step - loss: 0.1783 - accuracy: 0.9781 - val_loss: 0.1953 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 413/500
# 1/1 [==============================] - 0s 313ms/step - loss: 0.1811 - accuracy: 0.9750 - val_loss: 0.1953 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 414/500
# 1/1 [==============================] - 0s 303ms/step - loss: 0.1827 - accuracy: 0.9781 - val_loss: 0.1952 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 415/500
# 1/1 [==============================] - 0s 259ms/step - loss: 0.1777 - accuracy: 0.9770 - val_loss: 0.1951 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 416/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1668 - accuracy: 0.9801 - val_loss: 0.1951 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 417/500
# 1/1 [==============================] - 0s 278ms/step - loss: 0.1803 - accuracy: 0.9786 - val_loss: 0.1950 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 418/500
# 1/1 [==============================] - 0s 250ms/step - loss: 0.1783 - accuracy: 0.9760 - val_loss: 0.1950 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 419/500
# 1/1 [==============================] - 0s 278ms/step - loss: 0.1752 - accuracy: 0.9786 - val_loss: 0.1950 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 420/500
# 1/1 [==============================] - 0s 311ms/step - loss: 0.1755 - accuracy: 0.9816 - val_loss: 0.1949 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 421/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1813 - accuracy: 0.9730 - val_loss: 0.1949 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 422/500
# 1/1 [==============================] - 0s 314ms/step - loss: 0.1756 - accuracy: 0.9811 - val_loss: 0.1949 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 423/500
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1765 - accuracy: 0.9770 - val_loss: 0.1949 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 424/500
# 1/1 [==============================] - 0s 325ms/step - loss: 0.1871 - accuracy: 0.9730 - val_loss: 0.1948 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 425/500
# 1/1 [==============================] - 0s 342ms/step - loss: 0.1760 - accuracy: 0.9791 - val_loss: 0.1948 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 426/500
# 1/1 [==============================] - 0s 336ms/step - loss: 0.1750 - accuracy: 0.9806 - val_loss: 0.1947 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 427/500
# 1/1 [==============================] - 0s 334ms/step - loss: 0.1919 - accuracy: 0.9714 - val_loss: 0.1947 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 428/500
# 1/1 [==============================] - 0s 312ms/step - loss: 0.1749 - accuracy: 0.9816 - val_loss: 0.1947 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 429/500
# 1/1 [==============================] - 0s 316ms/step - loss: 0.1841 - accuracy: 0.9760 - val_loss: 0.1947 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 430/500
# 1/1 [==============================] - 0s 317ms/step - loss: 0.1781 - accuracy: 0.9755 - val_loss: 0.1947 - val_accuracy: 0.9464 - lr: 5.0000e-06
# Epoch 431/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.1697 - accuracy: 0.9837 - val_loss: 0.1946 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 432/500
# 1/1 [==============================] - 0s 299ms/step - loss: 0.1756 - accuracy: 0.9791 - val_loss: 0.1946 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 433/500
# 1/1 [==============================] - 0s 306ms/step - loss: 0.1811 - accuracy: 0.9791 - val_loss: 0.1945 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 434/500
# 1/1 [==============================] - 0s 288ms/step - loss: 0.1806 - accuracy: 0.9770 - val_loss: 0.1945 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 435/500
# 1/1 [==============================] - 0s 311ms/step - loss: 0.1791 - accuracy: 0.9770 - val_loss: 0.1944 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 436/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1784 - accuracy: 0.9791 - val_loss: 0.1944 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 437/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1795 - accuracy: 0.9750 - val_loss: 0.1943 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 438/500
# 1/1 [==============================] - 0s 314ms/step - loss: 0.1680 - accuracy: 0.9770 - val_loss: 0.1943 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 439/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.1636 - accuracy: 0.9806 - val_loss: 0.1942 - val_accuracy: 0.9500 - lr: 5.0000e-06
# Epoch 440/500
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1731 - accuracy: 0.9821 - val_loss: 0.1942 - val_accuracy: 0.9500 - lr: 5.0000e-06
# Epoch 441/500
# 1/1 [==============================] - 0s 314ms/step - loss: 0.1694 - accuracy: 0.9765 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 442/500
# 1/1 [==============================] - 0s 269ms/step - loss: 0.1785 - accuracy: 0.9781 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 443/500
# 1/1 [==============================] - 0s 309ms/step - loss: 0.1703 - accuracy: 0.9791 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 444/500
# 1/1 [==============================] - 0s 267ms/step - loss: 0.1699 - accuracy: 0.9781 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 445/500
# 1/1 [==============================] - 0s 294ms/step - loss: 0.1759 - accuracy: 0.9776 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 446/500
# 1/1 [==============================] - 0s 309ms/step - loss: 0.1783 - accuracy: 0.9811 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 447/500
# 1/1 [==============================] - 0s 300ms/step - loss: 0.1756 - accuracy: 0.9760 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 448/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.1711 - accuracy: 0.9781 - val_loss: 0.1943 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 449/500
# 1/1 [==============================] - 0s 269ms/step - loss: 0.1776 - accuracy: 0.9770 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 450/500
# 1/1 [==============================] - 0s 293ms/step - loss: 0.1817 - accuracy: 0.9781 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 451/500
# 1/1 [==============================] - 0s 291ms/step - loss: 0.1822 - accuracy: 0.9770 - val_loss: 0.1942 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 452/500
# 1/1 [==============================] - 0s 313ms/step - loss: 0.1666 - accuracy: 0.9811 - val_loss: 0.1941 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 453/500
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1782 - accuracy: 0.9765 - val_loss: 0.1941 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 454/500
# 1/1 [==============================] - 0s 286ms/step - loss: 0.1698 - accuracy: 0.9745 - val_loss: 0.1941 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 455/500
# 1/1 [==============================] - 0s 295ms/step - loss: 0.1740 - accuracy: 0.9811 - val_loss: 0.1940 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 456/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.1730 - accuracy: 0.9791 - val_loss: 0.1939 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 457/500
# 1/1 [==============================] - 0s 298ms/step - loss: 0.1705 - accuracy: 0.9811 - val_loss: 0.1938 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 458/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.1684 - accuracy: 0.9821 - val_loss: 0.1938 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 459/500
# 1/1 [==============================] - 0s 314ms/step - loss: 0.1781 - accuracy: 0.9791 - val_loss: 0.1937 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 460/500
# 1/1 [==============================] - 0s 271ms/step - loss: 0.1767 - accuracy: 0.9776 - val_loss: 0.1937 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 461/500
# 1/1 [==============================] - 0s 290ms/step - loss: 0.1807 - accuracy: 0.9745 - val_loss: 0.1937 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 462/500
# 1/1 [==============================] - 0s 320ms/step - loss: 0.1829 - accuracy: 0.9719 - val_loss: 0.1936 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 463/500
# 1/1 [==============================] - 0s 326ms/step - loss: 0.1722 - accuracy: 0.9786 - val_loss: 0.1935 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 464/500
# 1/1 [==============================] - 0s 316ms/step - loss: 0.1648 - accuracy: 0.9791 - val_loss: 0.1934 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 465/500
# 1/1 [==============================] - 0s 376ms/step - loss: 0.1690 - accuracy: 0.9801 - val_loss: 0.1933 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 466/500
# 1/1 [==============================] - 0s 348ms/step - loss: 0.1665 - accuracy: 0.9837 - val_loss: 0.1933 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 467/500
# 1/1 [==============================] - 0s 332ms/step - loss: 0.1817 - accuracy: 0.9770 - val_loss: 0.1932 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 468/500
# 1/1 [==============================] - 0s 344ms/step - loss: 0.1780 - accuracy: 0.9770 - val_loss: 0.1932 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 469/500
# 1/1 [==============================] - 0s 337ms/step - loss: 0.1791 - accuracy: 0.9781 - val_loss: 0.1931 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 470/500
# 1/1 [==============================] - 0s 311ms/step - loss: 0.1716 - accuracy: 0.9765 - val_loss: 0.1930 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 471/500
# 1/1 [==============================] - 0s 311ms/step - loss: 0.1734 - accuracy: 0.9781 - val_loss: 0.1929 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 472/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.1769 - accuracy: 0.9770 - val_loss: 0.1929 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 473/500
# 1/1 [==============================] - 0s 314ms/step - loss: 0.1837 - accuracy: 0.9719 - val_loss: 0.1928 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 474/500
# 1/1 [==============================] - 0s 314ms/step - loss: 0.1703 - accuracy: 0.9776 - val_loss: 0.1928 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 475/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.1712 - accuracy: 0.9816 - val_loss: 0.1927 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 476/500
# 1/1 [==============================] - 0s 279ms/step - loss: 0.1770 - accuracy: 0.9770 - val_loss: 0.1926 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 477/500
# 1/1 [==============================] - 0s 267ms/step - loss: 0.1802 - accuracy: 0.9770 - val_loss: 0.1925 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 478/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.1830 - accuracy: 0.9740 - val_loss: 0.1924 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 479/500
# 1/1 [==============================] - 0s 252ms/step - loss: 0.1776 - accuracy: 0.9786 - val_loss: 0.1924 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 480/500
# 1/1 [==============================] - 0s 284ms/step - loss: 0.1704 - accuracy: 0.9801 - val_loss: 0.1924 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 481/500
# 1/1 [==============================] - 0s 325ms/step - loss: 0.1743 - accuracy: 0.9730 - val_loss: 0.1924 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 482/500
# 1/1 [==============================] - 0s 303ms/step - loss: 0.1834 - accuracy: 0.9765 - val_loss: 0.1924 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 483/500
# 1/1 [==============================] - 0s 321ms/step - loss: 0.1737 - accuracy: 0.9765 - val_loss: 0.1923 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 484/500
# 1/1 [==============================] - 0s 303ms/step - loss: 0.1762 - accuracy: 0.9781 - val_loss: 0.1923 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 485/500
# 1/1 [==============================] - 0s 282ms/step - loss: 0.1733 - accuracy: 0.9781 - val_loss: 0.1923 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 486/500
# 1/1 [==============================] - 0s 275ms/step - loss: 0.1785 - accuracy: 0.9781 - val_loss: 0.1922 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 487/500
# 1/1 [==============================] - 0s 310ms/step - loss: 0.1721 - accuracy: 0.9791 - val_loss: 0.1922 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 488/500
# 1/1 [==============================] - 0s 285ms/step - loss: 0.1755 - accuracy: 0.9770 - val_loss: 0.1921 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 489/500
# 1/1 [==============================] - 0s 307ms/step - loss: 0.1753 - accuracy: 0.9796 - val_loss: 0.1921 - val_accuracy: 0.9476 - lr: 5.0000e-06
# Epoch 490/500
# 1/1 [==============================] - 0s 305ms/step - loss: 0.1727 - accuracy: 0.9791 - val_loss: 0.1921 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 491/500
# 1/1 [==============================] - 0s 314ms/step - loss: 0.1667 - accuracy: 0.9781 - val_loss: 0.1920 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 492/500
# 1/1 [==============================] - 0s 270ms/step - loss: 0.1763 - accuracy: 0.9760 - val_loss: 0.1920 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 493/500
# 1/1 [==============================] - 0s 281ms/step - loss: 0.1748 - accuracy: 0.9791 - val_loss: 0.1919 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 494/500
# 1/1 [==============================] - 0s 310ms/step - loss: 0.1739 - accuracy: 0.9765 - val_loss: 0.1919 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 495/500
# 1/1 [==============================] - 0s 315ms/step - loss: 0.1798 - accuracy: 0.9755 - val_loss: 0.1918 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 496/500
# 1/1 [==============================] - 0s 311ms/step - loss: 0.1655 - accuracy: 0.9806 - val_loss: 0.1918 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 497/500
# 1/1 [==============================] - 0s 296ms/step - loss: 0.1649 - accuracy: 0.9842 - val_loss: 0.1917 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 498/500
# 1/1 [==============================] - 0s 295ms/step - loss: 0.1824 - accuracy: 0.9776 - val_loss: 0.1916 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 499/500
# 1/1 [==============================] - 0s 289ms/step - loss: 0.1587 - accuracy: 0.9842 - val_loss: 0.1915 - val_accuracy: 0.9488 - lr: 5.0000e-06
# Epoch 500/500
# 1/1 [==============================] - 0s 295ms/step - loss: 0.1701 - accuracy: 0.9765 - val_loss: 0.1915 - val_accuracy: 0.9488 - lr: 5.0000e-06

# %% [markdown]
# 6.Plotting results

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
Y_pred = DD_Net.predict([X_test_0,X_test_1, D_test,A_test])
labels = ['Grab', 'Tap', 'Expand', 'Pinch', 'RC', 'RCC', 'SR', 'SL', 'SU', 'SD', 'SX', 'S+', 'SV', 'Shake']

y_true = []
for i in np.argmax(Y_test,axis=1):
    y_true.append(labels[i])

y_pred = []
for i in np.argmax(Y_pred,axis=1):
    y_pred.append(labels[i])

cm_analysis(y_true,y_pred, 'SHREC_14.png', labels, ymap=None, figsize=(8,8))
# Out:
# 27/27 [==============================] - 3s 32ms/step
